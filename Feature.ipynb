# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
train_df=pd.read_csv('data/train_imp.csv')

# %%
test_df=pd.read_csv('data/test_imp.csv')

# %%
all_df=pd.concat([train_df,test_df])

# %%
train_df
# Out:
#             id  loading  attribute_2  attribute_3  measurement_0  \
# 0          0.0    80.10          9.0          5.0            7.0
# 1          1.0    84.89          9.0          5.0           14.0
# 2          2.0    82.43          9.0          5.0           12.0
# 3          3.0   101.07          9.0          5.0           13.0
# 4          4.0   188.06          9.0          5.0            9.0
# ...        ...      ...          ...          ...            ...
# 26565  26565.0   158.95          6.0          9.0            6.0
# 26566  26566.0   146.02          6.0          9.0           10.0
# 26567  26567.0   115.62          6.0          9.0            1.0
# 26568  26568.0   106.38          6.0          9.0            2.0
# 26569  26569.0   131.20          6.0          9.0            6.0
#
#        measurement_1  measurement_2  measurement_3  measurement_4  \
# 0                8.0            4.0         18.040      12.518000
# ...

# %%
test_df
# Out:
#             id  loading  attribute_2  attribute_3  measurement_0  \
# 0      26570.0   119.57          6.0          4.0            6.0
# 1      26571.0   113.51          6.0          4.0           11.0
# 2      26572.0   112.16          6.0          4.0            8.0
# 3      26573.0   112.72          6.0          4.0            8.0
# 4      26574.0   208.00          6.0          4.0           14.0
# ...        ...      ...          ...          ...            ...
# 20770  47340.0   144.74          9.0          5.0            0.0
# 20771  47341.0    74.53          9.0          5.0            4.0
# 20772  47342.0    67.73          9.0          5.0           10.0
# 20773  47343.0   126.15          9.0          5.0            8.0
# 20774  47344.0    85.97          9.0          5.0            0.0
#
#        measurement_1  measurement_2  measurement_3  measurement_4  \
# 0                9.0            6.0         19.305      10.178000
# ...

# %%
ssss

# %%
a0_labels = {'material_7' : 7,
            'material_5': 5}
a1_labels = {'material_5': 5,
            'material_6': 6,
            'material_7': 7,
            'material_8': 8}
pc_labels = {'A': 0,
            'B': 1,
            'C': 2,
            'D': 3,
            'E': 4,
            'F': 5,
            'G': 6,
            'H': 7,
            'I': 8}

# %%
all_df['attribute_0'].replace(a0_labels, inplace = True)
all_df['attribute_1'].replace(a1_labels, inplace = True)
all_df['product_code'].replace(pc_labels, inplace = True)

# %%
#all_df=all_df.drop(['attribute_0','attribute_1','attribute_2','attribute_3'], axis=1)

# %%
train_df=all_df[~all_df['failure'].isnull()]
train_df
# Out:
#             id  loading  attribute_2  attribute_3  measurement_0  \
# 0          0.0    80.10          9.0          5.0            7.0
# 1          1.0    84.89          9.0          5.0           14.0
# 2          2.0    82.43          9.0          5.0           12.0
# 3          3.0   101.07          9.0          5.0           13.0
# 4          4.0   188.06          9.0          5.0            9.0
# ...        ...      ...          ...          ...            ...
# 26565  26565.0   158.95          6.0          9.0            6.0
# 26566  26566.0   146.02          6.0          9.0           10.0
# 26567  26567.0   115.62          6.0          9.0            1.0
# 26568  26568.0   106.38          6.0          9.0            2.0
# 26569  26569.0   131.20          6.0          9.0            6.0
#
#        measurement_1  measurement_2  measurement_3  measurement_4  \
# 0                8.0            4.0         18.040      12.518000
# ...

# %%
test_df=all_df[all_df['failure'].isnull()]
test_df
# Out:
#             id  loading  attribute_2  attribute_3  measurement_0  \
# 0      26570.0   119.57          6.0          4.0            6.0
# 1      26571.0   113.51          6.0          4.0           11.0
# 2      26572.0   112.16          6.0          4.0            8.0
# 3      26573.0   112.72          6.0          4.0            8.0
# 4      26574.0   208.00          6.0          4.0           14.0
# ...        ...      ...          ...          ...            ...
# 20770  47340.0   144.74          9.0          5.0            0.0
# 20771  47341.0    74.53          9.0          5.0            4.0
# 20772  47342.0    67.73          9.0          5.0           10.0
# 20773  47343.0   126.15          9.0          5.0            8.0
# 20774  47344.0    85.97          9.0          5.0            0.0
#
#        measurement_1  measurement_2  measurement_3  measurement_4  \
# 0                9.0            6.0         19.305      10.178000
# ...

# %%
ssss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-291291203478> in <module>
# ----> 1 ssss
#
# NameError: name 'ssss' is not defined

# %%
from datetime import datetime
now = datetime.now()
current_time = now.strftime("%Y_%m_%d_%H_%M_%S")
print("Current Time =", current_time)
train_df.to_pickle('feature/'+current_time+'_train.pkl')  
test_df.to_pickle('feature/'+current_time+'_test.pkl')
# Out:
# Current Time = 2022_08_04_14_57_03

# %%
ssss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-291291203478> in <module>
# ----> 1 ssss
#
# NameError: name 'ssss' is not defined
